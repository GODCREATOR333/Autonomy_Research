# %%
# Importing all the ore functions and libs

import jax as jnp
import numpy as np
from jax import grad,jit,vmap,pmap
from jax import lax
from jax import make_jaxpr
from jax import random
from jax import device_put
import matplotlib.pyplot as plt

# %%
x_jnp = jnp.numpy.linspace(0,10,1000)
y_jnp = 2*jnp.numpy.sin(x_jnp)+np.cos(x_jnp)
plt.plot(x_jnp,y_jnp )

# %%
seed = 0
key = random.PRNGKey(seed)

x = random.normal(key,(10,))
print(type(x),x)
# Out:
# <class 'jaxlib.xla_extension.ArrayImpl'> [-0.3721109   0.26423115 -0.18252768 -0.7368197  -0.44030377 -0.1521442
#  -0.67135346 -0.5908641   0.73168886  0.5673026 ]
